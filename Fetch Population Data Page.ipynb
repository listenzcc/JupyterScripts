# %% [markdown]
# # Fetch Population Data Page
#
# The perception of the 'Page' is the entry of the LEFT panel of the website of
#
# ```text
# url = http://www.stats.gov.cn/tjsj/pcsj/rkpc/6rp/indexch.htm
# ```

# %%
import pandas as pd

# %%
fetched = pd.read_html('http://www.stats.gov.cn/tjsj/pcsj/rkpc/6rp/html/A0101a.htm')

# %%
df = fetched[0].dropna()
df
# Out:
#                    0                  1                  2   \
# 0   1-1 各地区户数、人口数和性别比  1-1 各地区户数、人口数和性别比  1-1 各地区户数、人口数和性别比
# 3                 地 区                户 数                户 数
# 4                 地 区                 合计                家庭户
# 5                 地 区                 合计                家庭户
# 6                 地 区                 合计                家庭户
# 7                 全 国          417722698          401934196
# 8                 北 京            7355291            6680552
# 9                 天 津            3963604            3661992
# 10                河 北           20813492           20395116
# 11                山 西           10654162           10330207
# 12              内 蒙 古            8470472            8205498
# 13                辽 宁           15334912           14994046
# 14                吉 林            9162183            8998492
# 15              黑 龙 江           13192935           13000088
# 16                上 海            8893483            8253257
# ...
