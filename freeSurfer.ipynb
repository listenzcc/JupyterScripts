# %%
import os
import numpy as np
import pandas as pd
import plotly.express as px

# %%
folder = r'./freeSurferObj/'

objs = [os.path.join(folder, e) for e in os.listdir(folder)]
objs
# Out:
# ['./freeSurferObj/lh.pial.obj',
#  './freeSurferObj/surface.csv',
#  './freeSurferObj/vertex.csv']

# %%
select = objs[0]
select
# Out:
# './freeSurferObj/lh.pial.obj'

# %%
content = open(select).read()

# %%
lines = content.split('\n')
lines
# Out:
# ['v -38.834549 -19.019356 66.908409',
#  'v -16.554127 -69.255852 60.977936',
#  'v -9.553576 -8.218807 46.251862',
#  'v -23.755947 41.976662 24.649857',
#  'v -60.119377 0.131351 9.204027',
#  'v -50.369820 -48.500275 47.946831',
#  'v -36.782997 -87.543190 -0.980254',
#  'v -20.224998 -62.329872 6.908006',
#  'v -1.676775 9.333529 -4.029366',
#  'v -28.735180 23.722635 -6.297582',
#  'v -54.017925 -24.491703 -6.139310',
#  'v -35.112019 -24.750549 -25.246220',
#  'v -54.968189 -8.209369 38.579960',
#  'v -38.459175 22.735081 24.533545',
#  'v -30.142481 10.595556 56.340649',
#  'v -49.201927 -28.860157 53.224220',
#  'v -59.966351 -25.013794 28.201639',
#  'v -21.771652 -35.490829 70.654808',
#  'v -28.706177 -51.363464 40.162739',
#  'v -13.857485 -11.428417 71.010056',
#  'v -15.250265 -44.260601 54.576599',
#  'v -3.433147 34.760216 51.931252',
#  'v -10.076988 52.344421 3.327262',
#  'v -2.473145 16.168140 24.524197',
#  'v -41.024101 51.990612 -2.532902',
#  'v -12.623372 26.418808 -24.478134',
#  'v -35.715981 15.571591 7.095279',
#  'v -34.191456 -30.712702 17.196230',
#  'v -46.469559 -10.661004 -8.460791',
#  'v -64.595291 -49.226082 15.074936',
#  'v -43.120659 -66.507309 27.962427',
#  'v -61.400787 -58.404408 -3.142787',
#  'v -25.257374 -79.539375 17.358143',
#  'v -12.011393 -68.927460 33.454079',
#  'v -11.896334 -91.317375 2.784436',
#  'v -1.157686 -33.174019 29.549805',
#  'v -6.747331 -30.630255 9.453132',
#  'v -23.674768 8.458643 -32.272594',
#  'v -34.870033 -26.384634 -11.694664',
#  'v -55.841949 -20.224247 -27.426596',
#  'v -44.472546 -65.302002 -21.605703',
#  'v -19.245758 -56.957874 -9.127146',
#  'v -41.898525 -13.715841 49.125454',
#  'v -43.288746 5.078854 48.418648',
#  'v -29.544037 -7.581069 46.825043',
#  'v -38.250530 -26.340734 49.788197',
#  'v -41.615936 -21.355824 39.142323',
#  'v -22.731136 -28.798914 53.848015',
#  'v -37.272331 -35.033333 66.339516',
#  'v -23.528509 -14.966647 65.677780',
#  'v -12.564888 -30.846100 66.394196',
#  'v -21.515888 0.633329 55.371716',
#  'v -15.816477 62.095478 15.629219',
#  'v -5.688671 49.506096 26.335037',
#  'v -17.278183 47.698502 41.015373',
#  'v -30.130611 48.218304 11.693718',
#  'v -19.266354 59.886864 -5.995881',
#  'v -39.568890 38.031715 32.058434',
#  'v -36.065434 35.657127 12.150660',
#  'v -46.059059 -14.152608 15.295047',
#  'v -36.716789 -10.570656 14.619492',
#  'v -49.019329 6.918002 -2.050940',
#  'v -65.663078 -16.549953 18.307274',
#  'v -48.311676 -27.454601 15.997923',
#  'v -52.811634 -63.197472 36.701607',
#  'v -43.990993 -55.441357 20.554449',
#  'v -56.990704 -53.094902 31.060160',
#  'v -38.500195 -50.096977 36.657001',
#  'v -37.912590 -67.339355 49.178520',
#  'v -5.913734 -74.672012 47.128231',
#  'v -16.155090 -88.315918 38.198280',
#  'v -20.626547 -68.139267 38.483284',
#  'v -7.425181 -56.614380 60.761639',
#  'v -7.750725 -55.284019 44.323162',
#  'v -6.500800 6.812588 38.641731',
#  'v -3.211910 -10.105825 31.247513',
#  'v -7.294929 -18.910433 42.049263',
#  'v -2.091126 21.212372 -21.717878',
#  'v -14.615305 -4.131710 -12.794278',
#  'v -5.641984 -16.865200 -20.148769',
#  'v -39.848431 -3.732686 -5.752017',
#  'v -42.451714 11.082695 -21.148846',
#  'v -36.150867 5.521148 -18.023062',
#  'v -53.719147 -38.766758 -4.865104',
#  'v -60.642841 -39.645176 -16.621073',
#  'v -59.530434 -19.588451 -12.425695',
#  'v -21.210911 -102.186203 -7.753510',
#  'v -19.354599 -87.941231 -8.953952',
#  'v -44.580284 -82.371971 -15.471906',
#  'v -6.000800 -46.558277 4.862864',
#  'v -12.565356 -39.340126 -1.214850',
#  'v -16.433292 -62.959522 2.055828',
#  'v -61.572430 1.233920 27.187046',
#  'v -44.508614 6.406948 20.260197',
#  'v -37.585651 2.237385 30.890087',
#  'v -41.284966 23.332600 41.256523',
#  'v -24.855698 26.790930 35.859371',
#  'v -39.493378 -34.326324 37.594006',
#  'v -58.690960 -32.805359 42.959919',
#  'v -50.261311 -25.393997 37.358471',
#  'v -55.073570 -10.845823 32.230930',
#  'v -20.675888 -51.133461 60.405750',
#  'v -26.121765 -59.087898 52.970325',
#  'v -32.542778 -45.643768 59.299072',
#  'v -32.514885 -40.191578 44.395554',
#  'v -6.547942 -10.910381 57.989220',
#  'v -12.085365 -28.255650 44.417397',
#  'v -3.467479 -28.013836 60.840096',
#  'v -13.132878 -43.159393 73.244186',
#  'v -25.866537 25.491861 51.981182',
#  'v -12.074118 11.927996 64.846954',
#  'v -7.313207 11.838595 49.616508',
#  'v -2.516820 38.415157 -8.547678',
#  'v -0.037138 18.276768 9.028701',
#  'v -4.738959 40.726433 15.334859',
#  'v -9.474477 23.758997 31.883343',
#  'v -46.650402 32.900764 -16.999411',
#  'v -30.757183 23.973604 -23.936075',
#  'v -24.899664 42.209724 -13.216606',
#  'v -1.365098 48.392681 -23.814604',
#  'v -56.582500 22.111294 18.149971',
#  'v -51.075451 29.032776 -2.603821',
#  'v -30.194565 25.317997 6.393514',
#  'v -53.056847 -23.591434 2.315306',
#  'v -62.669525 -7.923790 -2.992438',
#  'v -39.776047 -23.867767 1.668861',
#  'v -40.483559 -5.759608 7.412128',
#  'v -52.303505 -41.258369 28.378378',
#  'v -47.675690 -37.373817 13.266027',
#  'v -64.484230 -35.817158 3.100495',
#  'v -46.415974 -77.010803 15.158501',
#  'v -41.444458 -68.631729 0.541480',
#  'v -46.330742 -64.521568 11.816401',
#  'v -49.820858 -48.942295 6.559274',
#  'v -26.222019 -65.680771 37.653118',
#  'v -36.296135 -85.133789 28.986721',
#  'v -31.675425 -93.344521 9.502344',
#  'v -19.341652 -63.446251 21.058022',
#  'v -13.593898 -77.815193 9.605763',
#  'v -2.709948 -74.833656 22.162247',
#  'v -11.693882 -98.134033 15.721949',
#  'v -10.030189 -37.393520 44.767227',
#  'v -10.495581 -54.486183 30.294392',
#  'v -2.186376 -51.352345 17.971125',
#  'v -1.992836 -14.691584 -0.633124',
#  'v 0.374676 -8.629421 15.678160',
#  'v 0.915289 -35.980408 22.253250',
#  'v -24.340763 2.813168 -14.315956',
#  'v -33.551643 -13.151680 -23.532896',
#  'v -30.734135 -6.594125 -36.184250',
#  'v -20.870275 -20.464218 -20.733999',
#  'v -51.742714 -2.652682 -23.456255',
#  'v -42.793728 0.299908 -40.166222',
#  'v -42.991596 -20.242014 -30.788696',
#  'v -46.893837 -59.823860 -9.738162',
#  'v -47.906555 -43.632252 -26.041285',
#  'v -34.970722 -45.320129 -24.686016',
#  'v -5.727883 -79.116379 -3.543268',
#  'v -28.042202 -65.178261 -7.306872',
#  'v -34.180923 -40.853649 -12.004324',
#  'v -18.649462 -32.176758 -5.850329',
#  'v -25.942215 -32.482300 -9.917422',
#  'v -41.698872 -13.518034 57.000847',
#  'v -40.119011 -5.307348 51.630077',
#  'v -34.432617 -8.931433 58.390362',
#  'v -36.584171 -25.940884 51.085865',
#  'v -34.170380 -19.329937 46.436565',
#  'v -28.602692 -25.639318 57.020241',
#  'v -30.103973 -28.734406 50.982449',
#  'v -32.305073 -14.460126 70.226608',
#  'v -24.789307 -24.946720 64.641708',
#  'v -26.828327 -11.102457 54.574207',
#  'v -24.869551 56.185577 24.366110',
#  'v -14.887018 54.776653 26.767879',
#  'v -24.006090 47.177227 35.415634',
#  'v -27.144526 46.874458 18.713406',
#  'v -26.176245 55.001404 11.357323',
#  'v -28.853815 36.134811 24.437075',
#  'v -36.103195 46.110912 22.528452',
#  'v -53.664970 -8.522663 6.711877',
#  'v -46.171627 -5.026831 5.899404',
#  'v -58.165306 4.024814 1.211382',
#  'v -64.117188 -8.757208 8.874668',
#  'v -55.699158 -16.544167 11.360034',
#  'v -52.025330 -54.770142 42.639843',
#  'v -49.596951 -54.408985 31.642315',
#  'v -53.239799 -49.778488 39.119152',
#  'v -43.594425 -49.779343 42.087154',
#  'v -46.463676 -57.562599 43.450569',
#  'v -10.033701 -72.478722 54.413219',
#  'v -15.942404 -75.794174 46.905617',
#  'v -16.681553 -67.157219 48.553886',
#  'v -12.502051 -60.551922 61.848278',
#  'v -7.364573 -62.020588 55.093159',
#  'v -9.446831 -0.927106 42.057522',
#  'v -4.644656 -6.031246 43.208496',
#  'v -11.203108 -13.099086 42.249706',
#  'v -3.454762 16.590937 -10.411074',
#  'v -3.963122 -0.031422 -13.943321',
#  'v -1.737422 -6.816220 -10.916413',
#  'v -39.210213 14.297195 -2.686810',
#  'v -40.882240 2.193135 -10.570345',
#  'v -33.237576 16.888058 -10.820818',
#  'v -48.665791 -32.001736 -5.785181',
#  'v -55.545521 -29.293482 -9.289996',
#  'v -50.688812 -22.993679 -10.351334',
#  'v -29.926823 -95.761353 -4.427309',
#  'v -30.640339 -94.764435 -16.504530',
#  'v -41.096176 -89.088165 -8.605035',
#  'v -14.347043 -56.693645 6.264488',
#  'v -20.654781 -55.397392 1.993007',
#  'v -24.892572 -64.449448 3.413956',
#  'v -59.597645 -2.279135 34.485722',
#  'v -48.701653 4.428272 30.821936',
#  'v -47.792900 -0.028820 35.942726',
#  'v -39.036888 4.827316 58.176292',
#  'v -45.056187 13.263140 46.299248',
#  'v -36.230732 21.334805 52.530407',
#  'v -32.060692 28.290985 43.690121',
#  'v -28.223648 17.203161 43.331295',
#  'v -41.319374 -31.018702 41.084743',
#  'v -44.115257 -29.009653 36.204758',
#  'v -50.155815 -26.781485 46.130249',
#  'v -41.116127 -15.227780 33.975372',
#  'v -47.367645 -16.916113 35.047798',
#  'v -46.486393 -10.165266 28.249130',
#  'v -51.693615 -8.567953 23.171818',
#  'v -22.104528 -43.327351 62.385010',
#  'v -27.300877 -47.924114 63.163979',
#  'v -23.394028 -40.401318 56.412788',
#  'v -45.331257 -32.830303 59.715363',
#  'v -36.849648 -37.988525 54.245697',
#  'v -38.719978 -35.219223 45.463573',
#  'v -33.917526 -36.644711 38.979176',
#  'v -7.379019 -8.829146 65.828873',
#  'v -4.751584 -20.715340 61.819099',
#  'v -3.466846 -17.358135 71.621925',
#  'v -14.474217 -33.865288 65.566437',
#  'v -5.630393 -38.262215 72.149094',
#  'v -16.353815 -37.592155 76.139572',
#  'v -19.533169 -48.681149 70.713158',
#  'v -22.547413 23.258406 39.445164',
#  'v -26.051525 14.033206 45.548103',
#  'v -21.722095 -5.911720 65.672676',
#  'v -22.280172 8.696882 65.494179',
#  'v -13.386019 -0.226328 72.285378',
#  'v -4.485175 -0.636457 67.760681',
#  'v -11.203625 45.053684 -2.082439',
#  'v -2.746219 40.858440 3.089238',
#  'v -9.510283 43.948261 7.436435',
#  'v -3.688329 43.133251 37.317398',
#  'v -4.279174 36.004143 27.977345',
#  'v -4.656877 29.108404 39.288406',
#  'v -8.016144 16.873981 40.615471',
#  'v -4.413784 21.574444 50.206177',
#  'v -45.514301 45.894913 -13.356619',
#  'v -33.819183 37.474892 -11.064569',
#  'v -34.444229 50.936180 -14.226664',
#  'v -5.524503 67.858360 -1.547194',
#  'v -5.490706 63.377674 -17.821148',
#  'v -3.707410 51.086494 -7.912950',
#  'v -8.857491 41.397392 -10.931071',
#  'v -38.196465 14.696413 25.198118',
#  'v -50.763050 12.551488 23.914759',
#  'v -43.358234 21.118191 22.055119',
#  'v -41.847363 44.518898 4.672975',
#  'v -45.924995 36.778484 6.723712',
#  'v -44.467495 38.588417 -3.2
# <b>limit_output extension: Maximum message size of 10000 exceeded with 37412 characters</b>

# %%
arr = np.array([len(e.split()) for e in lines])
arr, sorted(arr)
# Out:
# (array([4, 4, 4, ..., 4, 4, 0]),
#  [0,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   ...])

# %%
vertex = [e[1:].split() for e in lines if e.startswith('v')]
vertex = pd.DataFrame(vertex, columns=['x', 'y', 'z'])
vertex
# Out:
#                  x           y           z
# 0       -38.834549  -19.019356   66.908409
# 1       -16.554127  -69.255852   60.977936
# 2        -9.553576   -8.218807   46.251862
# 3       -23.755947   41.976662   24.649857
# 4       -60.119377    0.131351    9.204027
# ...            ...         ...         ...
# 163837  -34.380775  -25.065346  -24.719072
# 163838  -33.962822  -25.247301  -25.466833
# 163839  -34.570942  -24.759859  -26.428991
# 163840  -34.647511  -24.712444  -25.722996
# 163841  -35.078686  -24.759630  -25.221867
#
# [163842 rows x 3 columns]

# %%
surface = [e[1:].split() for e in lines if e.startswith('f')]
# surface = np.array(surface)
surface = pd.DataFrame(surface, columns=['a', 'b', 'c'])
surface
# Out:
#              a       b       c
# 0            1   40965   40963
# 1            1   40963   40966
# 2            1   40966   40968
# 3            1   40968   40970
# 4            1   40970   40965
# ...        ...     ...     ...
# 327675  163842  163841   92161
# 327676  163842   39991  163841
# 327677  163842  160927   39991
# 327678  163114  160927  163842
# 327679  163114      12  160927
#
# [327680 rows x 3 columns]

# %%
vertex.to_csv(os.path.join(folder, 'vertex.csv'))
surface.to_csv(os.path.join(folder, 'surface.csv'))

# %%
df['size'] = 1
df['symbol'] = 'o'
fig = px.scatter_3d(df, x='x', y='y', z='z', size='size', symbol='symbol', size_max=2)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28080/3253011379.py in <module>
# ----> 1 df['size'] = 1
#       2 df['symbol'] = 'o'
#       3 fig = px.scatter_3d(df, x='x', y='y', z='z', size='size', symbol='symbol', size_max=2)
#       4 fig.show()
#
# NameError: name 'df' is not defined
