# %%
import time

# %%
time.sleep(0.001)

# %%
num = 60
t = time.time()
for j in range(num):
    _t = time.time()
    time.sleep(0.001)
    print('>>', time.time()-_t)
print('==', time.time() - t)
# Out:
# >> 0.012529611587524414
# >> 0.0150146484375
# >> 0.015344619750976562
# >> 0.014818429946899414
# >> 0.015573978424072266
# >> 0.014999866485595703
# >> 0.015008926391601562
# >> 0.015142679214477539
# >> 0.014925718307495117
# >> 0.015459775924682617
# >> 0.015085935592651367
# >> 0.014649152755737305
# >> 0.015575170516967773
# >> 0.015094757080078125
# >> 0.01515340805053711
# >> 0.015319108963012695
# >> 0.014965295791625977
# >> 0.014852046966552734
# >> 0.014890432357788086
# >> 0.015192031860351562
# >> 0.0157473087310791
# >> 0.014791727066040039
# >> 0.015234231948852539
# >> 0.014748811721801758
# >> 0.014948844909667969
# >> 0.015036344528198242
# >> 0.014817476272583008
# >> 0.015326261520385742
# >> 0.014878511428833008
# >> 0.014983892440795898
# >> 0.014967918395996094
# >> 0.015619039535522461
# >> 0.015423059463500977
# >> 0.015030145645141602
# >> 0.014970779418945312
# >> 0.014821529388427734
# >> 0.015002012252807617
# >> 0.014998197555541992
# ...
